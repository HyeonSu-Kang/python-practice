# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
PROJ_path="/content/drive/MyDrive/Colab Notebooks/python-practice/"
# %cd "{PROJ_path}"
# %pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/python-practice
# '/content/drive/MyDrive/Colab Notebooks/python-practice'

# %%
# !git config user.email "dinokhsoo@gmail.com"
# !git config user.name "HyeonSu Kang"
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	start.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add prac1.ipynb
# !git commit -m "start initial commit"
# !git push origin main
# Out:
# fatal: pathspec 'prac1.ipynb' did not match any files
# error: pathspec 'm' did not match any file(s) known to git
# error: pathspec 'start initial commit' did not match any file(s) known to git
# Everything up-to-date
